# %%
import pandas as pd
import numpy as np
white_wine=pd.read_csv('../../practice/winequality-white.csv', sep=';')
red_wine=pd.read_csv('../../practice/winequality-red.csv', sep=';')
white_wine.columns=white_wine.columns.str.replace(' ','_')
red_wine.columns=red_wine.columns.str.replace(' ','_')
white_wine['wine_type']=0
red_wine['wine_type']=1
total_wine=pd.concat([white_wine, red_wine])

# %%
total_wine
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality  wine_type
# 0         8.8        6          0
# 1         9.5        6          0
# 2        10.1        6          0
# 3         9.9        6          0
# 4         9.9        6          0
# ...       ...      ...        ...
# 1594     10.5        5          1
# 1595     11.2        6          1
# 1596     11.0        6          1
# 1597     10.2        5          1
# 1598     11.0        6          1
#
# [6497 rows x 13 columns]

# %%
nrow = 3
ncolum=4
count=0
fig=plt.figure(figsize=(12,8))
for i in range(nrow):
    for j in range(ncolum):
        plt.subplot2grid((nrow,ncolum), (i,j))
        sns.histplot(white_wine[white_wine.columns[count]], bins=20, color='white',  edgecolor='black', linewidth=1.0)
        plt.ylabel('frequency')
        count +=1
    plt.tight_layout(pad=2)

# %%
df_w.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        2.613302          0.519770     0.567990        2.320468
# std         0.159515          0.089900     0.107615        1.003519
# min         1.949359          0.282843     0.000000        0.774597
# 25%         2.509980          0.458258     0.519615        1.303840
# 50%         2.607681          0.509902     0.565685        2.280351
# 75%         2.701851          0.565685     0.624500        3.146427
# max         3.768289          1.048809     1.288410        8.111720
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.210188             5.766252             11.618095     0.997008
# std       0.039921             1.434869              1.838811     0.001499
# min       0.094868             1.414214              3.000000     0.993534
# 25%       0.189737             4.795832             10.392305     0.995853
# 50%       0.207364             5.830952             11.575837     0.996865
# 75%       0.223607             6.782330             12.922848     0.998048
# max       0.588218            17.000000             20.976177     1.019304
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      1.785075     0.695406     3.237127     2.417478
# std       0.042101     0.079113     0.187831     0.183622
# min       1.649242     0.469042     2.828427     1.732051
# 25%       1.757840     0.640312     3.082207     2.236068
# 50%       1.783255     0.685565     3.224903     2.449490
# 75%       1.811077     0.741620     3.376389     2.449490
# max       1.954482     1.039230     3.768289     3.000000

# %%
df_w=np.sqrt(white_wine.loc[:,'fixed_acidity':'quality'])
nrow = 3
ncolum=4
count=0
fig=plt.figure(figsize=(12,8))
for i in range(nrow):
    for j in range(ncolum):
        plt.subplot2grid((nrow,ncolum), (i,j))
        sns.histplot(df_w[df_w.columns[count]], bins=20, color='white',  edgecolor='black', linewidth=1.0)
        plt.ylabel('frequency')
        count +=1
    plt.tight_layout(pad=2)

# %%
nrow = 3
ncolum=4
count=0
fig=plt.figure(figsize=(12,8))
for i in range(nrow):
    for j in range(ncolum):
        plt.subplot2grid((nrow,ncolum), (i,j))
        sns.histplot(red_wine[red_wine.columns[count]], bins=20, color='red',  edgecolor='black', linewidth=1.0)
        plt.ylabel('frequency')
        count +=1
    plt.tight_layout(pad=2)

# %%
dff= red_wine.loc[:,'total_sulfur_dioxide'].transform([np.reciprocal, np.square, np.sqrt,np.cbrt])
dff.hist(layout=(2,2))
# Out:
# array([[<AxesSubplot:title={'center':'reciprocal'}>,
#         <AxesSubplot:title={'center':'square'}>],
#        [<AxesSubplot:title={'center':'sqrt'}>,
#         <AxesSubplot:title={'center':'cbrt'}>]], dtype=object)

# %%
df_r.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        2.017049          0.797710     0.573765        1.337840
# std         0.135981          0.092036     0.236676        0.179776
# min         1.663103          0.493242     0.000000        0.965489
# 25%         1.921997          0.730614     0.448140        1.238562
# 50%         1.991632          0.804145     0.638250        1.300591
# 75%         2.095379          0.861774     0.748887        1.375069
# max         2.514581          1.164713     1.000000        2.493315
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.436584             2.397125              3.413073     0.998914
# std       0.053722             0.535717              0.797571     0.000630
# min       0.228943             1.000000              1.817121     0.996679
# 25%       0.412129             1.912931              2.802039     0.998531
# 50%       0.429084             2.410142              3.361975     0.998915
# 75%       0.448140             2.758924              3.957892     0.999278
# max       0.848556             4.160168              6.611489     1.001228
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      1.490116     0.864522     2.181953     1.775513
# std       0.023138     0.066930     0.072724     0.085495
# min       1.399319     0.691042     2.032793     1.442250
# 25%       1.475146     0.819321     2.117912     1.709976
# 50%       1.490308     0.852702     2.168703     1.817121
# 75%       1.503695     0.900411     2.230699     1.817121
# max       1.588723     1.259921     2.460719     2.000000

# %%
df_r=np.cbrt(red_wine.loc[:,'fixed_acidity':'quality'])
nrow = 3
ncolum=4
count=0
fig=plt.figure(figsize=(12,8))
for i in range(nrow):
    for j in range(ncolum):
        plt.subplot2grid((nrow,ncolum), (i,j))
        sns.histplot(df_r[df_r.columns[count]], bins=20, color='red',  edgecolor='black', linewidth=1.0)
        plt.ylabel('frequency')
        count +=1
    plt.tight_layout(pad=2)

# %%
df_r.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        2.017049          0.797710     0.573765        1.337840
# std         0.135981          0.092036     0.236676        0.179776
# min         1.663103          0.493242     0.000000        0.965489
# 25%         1.921997          0.730614     0.448140        1.238562
# 50%         1.991632          0.804145     0.638250        1.300591
# 75%         2.095379          0.861774     0.748887        1.375069
# max         2.514581          1.164713     1.000000        2.493315
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.436584             2.397125              3.413073     0.998914
# std       0.053722             0.535717              0.797571     0.000630
# min       0.228943             1.000000              1.817121     0.996679
# 25%       0.412129             1.912931              2.802039     0.998531
# 50%       0.429084             2.410142              3.361975     0.998915
# 75%       0.448140             2.758924              3.957892     0.999278
# max       0.848556             4.160168              6.611489     1.001228
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      1.490116     0.864522     2.181953     1.775513
# std       0.023138     0.066930     0.072724     0.085495
# min       1.399319     0.691042     2.032793     1.442250
# 25%       1.475146     0.819321     2.117912     1.709976
# 50%       1.490308     0.852702     2.168703     1.817121
# 75%       1.503695     0.900411     2.230699     1.817121
# max       1.588723     1.259921     2.460719     2.000000

# %%
import seaborn as sns
nrow = 3
ncolum=4
count=0
fig=plt.figure(figsize=(12,8))
for i in range(nrow):
    for j in range(ncolum):
        plt.subplot2grid((nrow,ncolum), (i,j))
        sns.histplot(total_wine[total_wine.columns[count]], bins=20, color='red',  edgecolor='black', linewidth=1.0)
        plt.ylabel('frequency')
        count +=1
    plt.tight_layout(pad=2)

# %%
df.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        2.676362          0.568075     0.543087        2.132667
# std         0.228919          0.130229     0.153927        0.946100
# min         1.949359          0.282843     0.000000        0.774597
# 25%         2.529822          0.479583     0.500000        1.341641
# 50%         2.645751          0.538516     0.556776        1.732051
# 75%         2.774887          0.632456     0.624500        2.846050
# max         3.987480          1.256981     1.288410        8.111720
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.229837             5.277589             10.342120     0.997344
# std       0.056649             1.634866              2.964200     0.001503
# min       0.094868             1.000000              2.449490     0.993534
# 25%       0.194936             4.123106              8.774964     0.996163
# 50%       0.216795             5.385165             10.862780     0.997442
# 75%       0.254951             6.403124             12.489996     0.998494
# max       0.781665            17.000000             20.976177     1.019304
#
#                 pH    sulphates      alcohol      quality
# count  6497.000000  6497.000000  6497.000000  6497.000000
# mean      1.793462     0.722528     3.233994     2.405276
# std       0.044648     0.096035     0.181906     0.181739
# min       1.649242     0.469042     2.828427     1.732051
# 25%       1.763519     0.655744     3.082207     2.236068
# 50%       1.791647     0.714143     3.209361     2.449490
# 75%       1.822087     0.774597     3.361547     2.449490
# max       2.002498     1.414214     3.860052     3.000000

# %%
df=np.sqrt(total_wine.loc[:,'fixed_acidity':'quality'])
#df['quality']=total_wine['quality']
nrow = 3
ncolum=4
count=0
fig=plt.figure(figsize=(12,8))
for i in range(nrow):
    for j in range(ncolum):
        plt.subplot2grid((nrow,ncolum), (i,j))
        sns.histplot(df[df.columns[count]], bins=20, color='red',  edgecolor='black', linewidth=1.0)
        plt.ylabel('frequency')
        count +=1
    plt.tight_layout(pad=2)

# %%
# so I use other method to remove outliers
def outliers_idr(df):
    
    num=df.count(axis=1)
    num_col=num[1]
    
    i=0
    for colu in df:
        mean_df=df[colu].mean()
        std_df=df[colu].std()
        df_out= df[(df[colu] <= 3*std_df+mean_df) & (df[colu] >= (mean_df-3*std_df))]
        df=df_out
        i=i+1
        
    return df_out





total_wine=outliers_remov(total_wine)
total_wine= total_wine.set_index(np.arange(len(total_wine)))

# %%
import seaborn as sns
nrow = 3
ncolum=4
count=0
fig=plt.figure(figsize=(12,8))
for i in range(nrow):
    for j in range(ncolum):
        plt.subplot2grid((nrow,ncolum), (i,j))
        sns.histplot(total_wine[total_wine.columns[count]], bins=20, color='red',  edgecolor='black', linewidth=1.0)
        plt.ylabel('frequency')
        count +=1
    plt.tight_layout(pad=2)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, cohen_kappa_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

cohen=[]
score=[]
confusion=[]
class_out=[]
for i in range(10): 
    model=LogisticRegression()
    x=total_wine.drop(columns='wine_type')
    y=total_wine['wine_type']
    x_train,x_test,y_train, y_test=train_test_split(x,y, test_size=0.3)
    scale=MinMaxScaler()
    x_train_n= scale.fit_transform(x_train)
    x_train_n= pd.DataFrame(x_train_n, columns=x_train.columns)
    x_test_n= scale.fit_transform(x_test)
    x_test_n= pd.DataFrame(x_test_n, columns=x_test.columns)
    model.fit(x_train_n, y_train)
    pred=model.predict(x_test_n)
    scor=accuracy_score(pred, y_test)
    score.append(scor)

    con=confusion_matrix(y_test, pred)
    confusion.append(con)
    class_p= classification_report(y_test,pred)
    class_out.append(class_p)
    cohe=cohen_kappa_score(y_test, pred)
    cohen.append(cohe)
    i +=1
print('score :\n', np.mean(score),'\ncohen: \n',np.mean(cohen),'\nconfusion \n',confusion, 'classification: \n',class_out)
# Out:
# score :
#  0.994974358974359
# cohen:
#  0.9862981747669289
# confusion
#  [array([[1483,    3],
#        [   6,  458]]), array([[1479,    3],
#        [   5,  463]]), array([[1452,    5],
#        [   5,  488]]), array([[1473,    7],
#        [   5,  465]]), array([[1483,    4],
#        [   6,  457]]), array([[1486,    6],
#        [   4,  454]]), array([[1483,    1],
#        [   6,  460]]), array([[1518,    2],
#        [   3,  427]]), array([[1446,    8],
#        [   5,  491]]), array([[1461,    7],
#        [   7,  475]])] classification:
#  ['              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1486\n         1.0       0.99      0.99      0.99       464\n\n    accuracy                           1.00      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1482\n         1.0       0.99      0.99      0.99       468\n\n    accuracy                           1.00      1950\n   macro avg       1.00      0.99      0.99      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1457\n         1.0       0.99      0.99      0.99       493\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1480\n         1.0       0.99      0.99      0.99       470\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1487\n         1.0       0.99      0.99      0.99       463\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1492\n         1.0       0.99      0.99      0.99       458\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1484\n         1.0       1.00      0.99      0.99       466\n\n    accuracy                           1.00      1950\n   macro avg       1.00      0.99      1.00      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1520\n         1.0       1.00      0.99      0.99       430\n\n    accuracy                           1.00      1950\n   macro avg       1.00      1.00      1.00      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      0.99      1.00      1454\n         1.0       0.98      0.99      0.99       496\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1468\n         1.0       0.99      0.99      0.99       482\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n']

# %%
# logistic model with standardisation
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, cohen_kappa_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

cohen=[]
score=[]
confusion=[]
class_out=[]
for i in range(10): 
    model=LogisticRegression()
    x=total_wine.drop(columns='wine_type')
    y=total_wine['wine_type']
    x_train,x_test,y_train, y_test=train_test_split(x,y, test_size=0.3)
    scale=StandardScaler()
    x_train_n= scale.fit_transform(x_train)
    x_train_n= pd.DataFrame(x_train_n, columns=x_train.columns)
    x_test_n= scale.fit_transform(x_test)
    x_test_n= pd.DataFrame(x_test_n, columns=x_test.columns)
    model.fit(x_train_n, y_train)
    pred=model.predict(x_test_n)
    scor=accuracy_score(pred, y_test)
    score.append(scor)

    con=confusion_matrix(y_test, pred)
    confusion.append(con)
    class_p= classification_report(y_test,pred)
    class_out.append(class_p)
    cohe=cohen_kappa_score(y_test, pred)
    cohen.append(cohe)
    i +=1
print('score :\n', np.mean(score),'\ncohen: \n',np.mean(cohen),'\nconfusion \n',confusion, 'classification: \n',class_out)
# Out:
# score :
#  0.9954358974358974
# cohen:
#  0.9876244287154069
# confusion
#  [array([[1489,    4],
#        [   4,  453]]), array([[1467,    1],
#        [   7,  475]]), array([[1472,    3],
#        [   3,  472]]), array([[1455,    2],
#        [   8,  485]]), array([[1449,    2],
#        [   6,  493]]), array([[1462,    1],
#        [   3,  484]]), array([[1504,    8],
#        [   3,  435]]), array([[1479,    7],
#        [   6,  458]]), array([[1443,    5],
#        [   8,  494]]), array([[1464,    4],
#        [   4,  478]])] classification:
#  ['              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1493\n         1.0       0.99      0.99      0.99       457\n\n    accuracy                           1.00      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1468\n         1.0       1.00      0.99      0.99       482\n\n    accuracy                           1.00      1950\n   macro avg       1.00      0.99      0.99      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1475\n         1.0       0.99      0.99      0.99       475\n\n    accuracy                           1.00      1950\n   macro avg       1.00      1.00      1.00      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      1.00      1457\n         1.0       1.00      0.98      0.99       493\n\n    accuracy                           0.99      1950\n   macro avg       1.00      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1451\n         1.0       1.00      0.99      0.99       499\n\n    accuracy                           1.00      1950\n   macro avg       1.00      0.99      0.99      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1463\n         1.0       1.00      0.99      1.00       487\n\n    accuracy                           1.00      1950\n   macro avg       1.00      1.00      1.00      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      0.99      1.00      1512\n         1.0       0.98      0.99      0.99       438\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1486\n         1.0       0.98      0.99      0.99       464\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      1.00      1448\n         1.0       0.99      0.98      0.99       502\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1468\n         1.0       0.99      0.99      0.99       482\n\n    accuracy                           1.00      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       1.00      1.00      1.00      1950\n']

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, cohen_kappa_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from matplotlib import pyplot as plt

cohen=[]
score=[]
confusion=[]
class_out=[]
for i in range(10): 
    model=DecisionTreeClassifier()
    x=total_wine.drop(columns='wine_type')
    y=total_wine['wine_type']
    x_train,x_test,y_train, y_test=train_test_split(x,y, test_size=0.3)
    scale=MinMaxScaler()
    x_train_n= scale.fit_transform(x_train)
    x_train_n= pd.DataFrame(x_train_n, columns=x_train.columns)
    x_test_n= scale.fit_transform(x_test)
    x_test_n= pd.DataFrame(x_test_n, columns=x_test.columns)
    model.fit(x_train_n, y_train)
    pred=model.predict(x_test_n)
    scor=accuracy_score(pred, y_test)
    score.append(scor)

    con=confusion_matrix(y_test, pred)
    confusion.append(con)
    class_p= classification_report(y_test,pred)
    class_out.append(class_p)
    cohe=cohen_kappa_score(y_test, pred)
    cohen.append(cohe)
    i +=1
print('score :\n', np.mean(score),'\ncohen: \n',np.mean(cohen),'\nconfusion \n',confusion, 'classification: \n',class_out)
# Out:
# score :
#  0.9847179487179487
# cohen:
#  0.9589077869547665
# confusion
#  [array([[1471,   13],
#        [  13,  453]]), array([[1466,   10],
#        [  25,  449]]), array([[1469,   11],
#        [  13,  457]]), array([[1459,   11],
#        [  13,  467]]), array([[1442,   13],
#        [  19,  476]]), array([[1448,   15],
#        [  20,  467]]), array([[1451,   16],
#        [  10,  473]]), array([[1448,   14],
#        [  13,  475]]), array([[1435,   10],
#        [  25,  480]]), array([[1450,   15],
#        [  19,  466]])] classification:
#  ['              precision    recall  f1-score   support\n\n         0.0       0.99      0.99      0.99      1484\n         1.0       0.97      0.97      0.97       466\n\n    accuracy                           0.99      1950\n   macro avg       0.98      0.98      0.98      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.98      0.99      0.99      1476\n         1.0       0.98      0.95      0.96       474\n\n    accuracy                           0.98      1950\n   macro avg       0.98      0.97      0.98      1950\nweighted avg       0.98      0.98      0.98      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      0.99      0.99      1480\n         1.0       0.98      0.97      0.97       470\n\n    accuracy                           0.99      1950\n   macro avg       0.98      0.98      0.98      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      0.99      0.99      1470\n         1.0       0.98      0.97      0.97       480\n\n    accuracy                           0.99      1950\n   macro avg       0.98      0.98      0.98      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      0.99      0.99      1455\n         1.0       0.97      0.96      0.97       495\n\n    accuracy                           0.98      1950\n   macro avg       0.98      0.98      0.98      1950\nweighted avg       0.98      0.98      0.98      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      0.99      0.99      1463\n         1.0       0.97      0.96      0.96       487\n\n    accuracy                           0.98      1950\n   macro avg       0.98      0.97      0.98      1950\nweighted avg       0.98      0.98      0.98      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      0.99      0.99      1467\n         1.0       0.97      0.98      0.97       483\n\n    accuracy                           0.99      1950\n   macro avg       0.98      0.98      0.98      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      0.99      0.99      1462\n         1.0       0.97      0.97      0.97       488\n\n    accuracy                           0.99      1950\n   macro avg       0.98      0.98      0.98      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.98      0.99      0.99      1445\n         1.0       0.98      0.95      0.96       505\n\n    accuracy                           0.98      1950\n   macro avg       0.98      0.97      0.98      1950\nweighted avg       0.98      0.98      0.98      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      0.99      0.99      1465\n         1.0       0.97      0.96      0.96       485\n\n    accuracy                           0.98      1950\n   macro avg       0.98      0.98      0.98      1950\nweighted avg       0.98      0.98      0.98      1950\n']

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, cohen_kappa_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from matplotlib import pyplot as plt

cohen=[]
score=[]
confusion=[]
class_out=[]
for i in range(10): 
    model=BaggingClassifier()
    x=total_wine.drop(columns='wine_type')
    y=total_wine['wine_type']
    x_train,x_test,y_train, y_test=train_test_split(x,y, test_size=0.3)
    scale=MinMaxScaler()
    x_train_n= scale.fit_transform(x_train)
    x_train_n= pd.DataFrame(x_train_n, columns=x_train.columns)
    x_test_n= scale.fit_transform(x_test)
    x_test_n= pd.DataFrame(x_test_n, columns=x_test.columns)
    model.fit(x_train_n, y_train)
    pred=model.predict(x_test_n)
    scor=accuracy_score(pred, y_test)
    score.append(scor)

    con=confusion_matrix(y_test, pred)
    confusion.append(con)
    class_p= classification_report(y_test,pred)
    class_out.append(class_p)
    cohe=cohen_kappa_score(y_test, pred)
    cohen.append(cohe)
    i +=1
print('score :\n', np.mean(score),'\ncohen: \n',np.mean(cohen),'\nconfusion \n',confusion, 'classification: \n',class_out)
# Out:
# score :
#  0.990871794871795
# cohen:
#  0.9747941115940802
# confusion
#  [array([[1485,    8],
#        [  14,  443]]), array([[1483,    5],
#        [  14,  448]]), array([[1454,    8],
#        [  12,  476]]), array([[1466,    4],
#        [   7,  473]]), array([[1490,    5],
#        [  13,  442]]), array([[1459,    4],
#        [  13,  474]]), array([[1490,    4],
#        [  10,  446]]), array([[1492,    6],
#        [  14,  438]]), array([[1480,    3],
#        [  16,  451]]), array([[1471,    5],
#        [  13,  461]])] classification:
#  ['              precision    recall  f1-score   support\n\n         0.0       0.99      0.99      0.99      1493\n         1.0       0.98      0.97      0.98       457\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.98      0.98      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      0.99      1488\n         1.0       0.99      0.97      0.98       462\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.98      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      0.99      0.99      1462\n         1.0       0.98      0.98      0.98       488\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.98      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1470\n         1.0       0.99      0.99      0.99       480\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      0.99      1495\n         1.0       0.99      0.97      0.98       455\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.98      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      0.99      1463\n         1.0       0.99      0.97      0.98       487\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      1.00      1494\n         1.0       0.99      0.98      0.98       456\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      0.99      1498\n         1.0       0.99      0.97      0.98       452\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.98      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      0.99      1483\n         1.0       0.99      0.97      0.98       467\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.98      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      0.99      1476\n         1.0       0.99      0.97      0.98       474\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.98      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n']

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, cohen_kappa_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

cohen=[]
score=[]
confusion=[]
class_out=[]
for i in range(10): 
    model=RandomForestClassifier()
    x=total_wine.drop(columns='wine_type')
    y=total_wine['wine_type']
    x_train,x_test,y_train, y_test=train_test_split(x,y, test_size=0.3)
    scale=MinMaxScaler()
    x_train_n= scale.fit_transform(x_train)
    x_train_n= pd.DataFrame(x_train_n, columns=x_train.columns)
    x_test_n= scale.fit_transform(x_test)
    x_test_n= pd.DataFrame(x_test_n, columns=x_test.columns)
    model.fit(x_train_n, y_train)
    pred=model.predict(x_test_n)
    scor=accuracy_score(pred, y_test)
    score.append(scor)

    con=confusion_matrix(y_test, pred)
    confusion.append(con)
    class_p= classification_report(y_test,pred)
    class_out.append(class_p)
    cohe=cohen_kappa_score(y_test, pred)
    cohen.append(cohe)
    i +=1
print('score :\n', np.mean(score),'\ncohen: \n',np.mean(cohen),'\nconfusion \n',confusion, 'classification: \n',class_out)
# Out:
# score :
#  0.9945128205128204
# cohen:
#  0.984934469003208
# confusion
#  [array([[1476,    2],
#        [   8,  464]]), array([[1477,    1],
#        [  10,  462]]), array([[1498,    3],
#        [   6,  443]]), array([[1447,    2],
#        [   9,  492]]), array([[1474,    1],
#        [  11,  464]]), array([[1480,    4],
#        [   5,  461]]), array([[1498,    2],
#        [   6,  444]]), array([[1481,    3],
#        [  12,  454]]), array([[1455,    0],
#        [  11,  484]]), array([[1493,    4],
#        [   7,  446]])] classification:
#  ['              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      1.00      1478\n         1.0       1.00      0.98      0.99       472\n\n    accuracy                           0.99      1950\n   macro avg       1.00      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      1.00      1478\n         1.0       1.00      0.98      0.99       472\n\n    accuracy                           0.99      1950\n   macro avg       1.00      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1501\n         1.0       0.99      0.99      0.99       449\n\n    accuracy                           1.00      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      1.00      1449\n         1.0       1.00      0.98      0.99       501\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      1.00      1475\n         1.0       1.00      0.98      0.99       475\n\n    accuracy                           0.99      1950\n   macro avg       1.00      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1484\n         1.0       0.99      0.99      0.99       466\n\n    accuracy                           1.00      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1500\n         1.0       1.00      0.99      0.99       450\n\n    accuracy                           1.00      1950\n   macro avg       1.00      0.99      0.99      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      0.99      1484\n         1.0       0.99      0.97      0.98       466\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      1.00      1455\n         1.0       1.00      0.98      0.99       495\n\n    accuracy                           0.99      1950\n   macro avg       1.00      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1497\n         1.0       0.99      0.98      0.99       453\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n']

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, cohen_kappa_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

cohen=[]
score=[]
confusion=[]
class_out=[]
for i in range(10): 
    model=LinearDiscriminantAnalysis()
    x=total_wine.drop(columns='wine_type')
    y=total_wine['wine_type']
    x_train,x_test,y_train, y_test=train_test_split(x,y, test_size=0.3)
    scale=MinMaxScaler()
    x_train_n= scale.fit_transform(x_train)
    x_train_n= pd.DataFrame(x_train_n, columns=x_train.columns)
    x_test_n= scale.fit_transform(x_test)
    x_test_n= pd.DataFrame(x_test_n, columns=x_test.columns)
    model.fit(x_train_n, y_train)
    pred=model.predict(x_test_n)
    scor=accuracy_score(pred, y_test)
    score.append(scor)

    con=confusion_matrix(y_test, pred)
    confusion.append(con)
    class_p= classification_report(y_test,pred)
    class_out.append(class_p)
    cohe=cohen_kappa_score(y_test, pred)
    cohen.append(cohe)
    i +=1
print('score :\n', np.mean(score),'\ncohen: \n',np.mean(cohen),'\nconfusion \n',confusion, 'classification: \n',class_out)
# Out:
# score :
#  0.9942051282051283
# cohen:
#  0.9842832866593468
# confusion
#  [array([[1484,    3],
#        [   8,  455]]), array([[1464,    2],
#        [  10,  474]]), array([[1449,    3],
#        [   8,  490]]), array([[1444,    3],
#        [   5,  498]]), array([[1472,    3],
#        [   8,  467]]), array([[1465,    6],
#        [   7,  472]]), array([[1492,    6],
#        [  12,  440]]), array([[1441,    3],
#        [   9,  497]]), array([[1489,    3],
#        [   5,  453]]), array([[1465,    4],
#        [   5,  476]])] classification:
#  ['              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      1.00      1487\n         1.0       0.99      0.98      0.99       463\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      1.00      1466\n         1.0       1.00      0.98      0.99       484\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      1.00      1452\n         1.0       0.99      0.98      0.99       498\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1447\n         1.0       0.99      0.99      0.99       503\n\n    accuracy                           1.00      1950\n   macro avg       1.00      0.99      0.99      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      1.00      1475\n         1.0       0.99      0.98      0.99       475\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1471\n         1.0       0.99      0.99      0.99       479\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      0.99      1498\n         1.0       0.99      0.97      0.98       452\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.98      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      1.00      1444\n         1.0       0.99      0.98      0.99       506\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1492\n         1.0       0.99      0.99      0.99       458\n\n    accuracy                           1.00      1950\n   macro avg       1.00      0.99      0.99      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1469\n         1.0       0.99      0.99      0.99       481\n\n    accuracy                           1.00      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       1.00      1.00      1.00      1950\n']

# %%
#standardization instead of normalisation for LinearDiscriminantAnalysis
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, cohen_kappa_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

cohen=[]
score=[]
confusion=[]
class_out=[]
for i in range(10): 
    model=LinearDiscriminantAnalysis()
    x=total_wine.drop(columns='wine_type')
    y=total_wine['wine_type']
    x_train,x_test,y_train, y_test=train_test_split(x,y, test_size=0.3)
    scale=StandardScaler()
    x_train_n= scale.fit_transform(x_train)
    x_train_n= pd.DataFrame(x_train_n, columns=x_train.columns)
    x_test_n= scale.fit_transform(x_test)
    x_test_n= pd.DataFrame(x_test_n, columns=x_test.columns)
    model.fit(x_train_n, y_train)
    pred=model.predict(x_test_n)
    scor=accuracy_score(pred, y_test)
    score.append(scor)

    con=confusion_matrix(y_test, pred)
    confusion.append(con)
    class_p= classification_report(y_test,pred)
    class_out.append(class_p)
    cohe=cohen_kappa_score(y_test, pred)
    cohen.append(cohe)
    i +=1
print('score :\n', np.mean(score),'\ncohen: \n',np.mean(cohen),'\nconfusion \n',confusion, 'classification: \n',class_out)
# Out:
# score :
#  0.9942564102564104
# cohen:
#  0.9842479952402806
# confusion
#  [array([[1488,    5],
#        [  10,  447]]), array([[1482,    6],
#        [   8,  454]]), array([[1487,    3],
#        [   9,  451]]), array([[1445,    2],
#        [   7,  496]]), array([[1489,    3],
#        [   6,  452]]), array([[1458,    5],
#        [   7,  480]]), array([[1479,    6],
#        [  10,  455]]), array([[1466,    3],
#        [   5,  476]]), array([[1457,    1],
#        [   7,  485]]), array([[1492,    4],
#        [   5,  449]])] classification:
#  ['              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      0.99      1493\n         1.0       0.99      0.98      0.98       457\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      1.00      1488\n         1.0       0.99      0.98      0.98       462\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      1.00      1490\n         1.0       0.99      0.98      0.99       460\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1447\n         1.0       1.00      0.99      0.99       503\n\n    accuracy                           1.00      1950\n   macro avg       1.00      0.99      0.99      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1492\n         1.0       0.99      0.99      0.99       458\n\n    accuracy                           1.00      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1463\n         1.0       0.99      0.99      0.99       487\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      0.99      1485\n         1.0       0.99      0.98      0.98       465\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1469\n         1.0       0.99      0.99      0.99       481\n\n    accuracy                           1.00      1950\n   macro avg       1.00      0.99      0.99      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1458\n         1.0       1.00      0.99      0.99       492\n\n    accuracy                           1.00      1950\n   macro avg       1.00      0.99      0.99      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1496\n         1.0       0.99      0.99      0.99       454\n\n    accuracy                           1.00      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       1.00      1.00      1.00      1950\n']

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, cohen_kappa_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

cohen=[]
score=[]
confusion=[]
class_out=[]
for i in range(10): 
    model=GaussianNB()
    x=total_wine.drop(columns='wine_type')
    y=total_wine['wine_type']
    x_train,x_test,y_train, y_test=train_test_split(x,y, test_size=0.3)
    scale=MinMaxScaler()
    x_train_n= scale.fit_transform(x_train)
    x_train_n= pd.DataFrame(x_train_n, columns=x_train.columns)
    x_test_n= scale.fit_transform(x_test)
    x_test_n= pd.DataFrame(x_test_n, columns=x_test.columns)
    model.fit(x_train_n, y_train)
    pred=model.predict(x_test_n)
    scor=accuracy_score(pred, y_test)
    score.append(scor)

    con=confusion_matrix(y_test, pred)
    confusion.append(con)
    class_p= classification_report(y_test,pred)
    class_out.append(class_p)
    cohe=cohen_kappa_score(y_test, pred)
    cohen.append(cohe)
    i +=1
print('score :\n', np.mean(score),'\ncohen: \n',np.mean(cohen),'\nconfusion \n',confusion, 'classification: \n',class_out)
# Out:
# score :
#  0.9842051282051282
# cohen:
#  0.9571384359097724
# confusion
#  [array([[1484,   25],
#        [   7,  434]]), array([[1467,   12],
#        [  14,  457]]), array([[1451,   21],
#        [  10,  468]]), array([[1453,   19],
#        [  15,  463]]), array([[1460,   18],
#        [  19,  453]]), array([[1471,   14],
#        [  13,  452]]), array([[1456,   15],
#        [  14,  465]]), array([[1456,   10],
#        [  18,  466]]), array([[1429,   27],
#        [   7,  487]]), array([[1468,   16],
#        [  14,  452]])] classification:
#  ['              precision    recall  f1-score   support\n\n         0.0       1.00      0.98      0.99      1509\n         1.0       0.95      0.98      0.96       441\n\n    accuracy                           0.98      1950\n   macro avg       0.97      0.98      0.98      1950\nweighted avg       0.98      0.98      0.98      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      0.99      0.99      1479\n         1.0       0.97      0.97      0.97       471\n\n    accuracy                           0.99      1950\n   macro avg       0.98      0.98      0.98      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      0.99      0.99      1472\n         1.0       0.96      0.98      0.97       478\n\n    accuracy                           0.98      1950\n   macro avg       0.98      0.98      0.98      1950\nweighted avg       0.98      0.98      0.98      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      0.99      0.99      1472\n         1.0       0.96      0.97      0.96       478\n\n    accuracy                           0.98      1950\n   macro avg       0.98      0.98      0.98      1950\nweighted avg       0.98      0.98      0.98      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      0.99      0.99      1478\n         1.0       0.96      0.96      0.96       472\n\n    accuracy                           0.98      1950\n   macro avg       0.97      0.97      0.97      1950\nweighted avg       0.98      0.98      0.98      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      0.99      0.99      1485\n         1.0       0.97      0.97      0.97       465\n\n    accuracy                           0.99      1950\n   macro avg       0.98      0.98      0.98      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      0.99      0.99      1471\n         1.0       0.97      0.97      0.97       479\n\n    accuracy                           0.99      1950\n   macro avg       0.98      0.98      0.98      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      0.99      0.99      1466\n         1.0       0.98      0.96      0.97       484\n\n    accuracy                           0.99      1950\n   macro avg       0.98      0.98      0.98      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      0.98      0.99      1456\n         1.0       0.95      0.99      0.97       494\n\n    accuracy                           0.98      1950\n   macro avg       0.97      0.98      0.98      1950\nweighted avg       0.98      0.98      0.98      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      0.99      0.99      1484\n         1.0       0.97      0.97      0.97       466\n\n    accuracy                           0.98      1950\n   macro avg       0.98      0.98      0.98      1950\nweighted avg       0.98      0.98      0.98      1950\n']

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, cohen_kappa_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

cohen=[]
score=[]
confusion=[]
class_out=[]
for i in range(10): 
    model=KNeighborsClassifier()
    x=total_wine.drop(columns='wine_type')
    y=total_wine['wine_type']
    x_train,x_test,y_train, y_test=train_test_split(x,y, test_size=0.3)
    scale=MinMaxScaler()
    x_train_n= scale.fit_transform(x_train)
    x_train_n= pd.DataFrame(x_train_n, columns=x_train.columns)
    x_test_n= scale.fit_transform(x_test)
    x_test_n= pd.DataFrame(x_test_n, columns=x_test.columns)
    model.fit(x_train_n, y_train)
    pred=model.predict(x_test_n)
    scor=accuracy_score(pred, y_test)
    score.append(scor)

    con=confusion_matrix(y_test, pred)
    confusion.append(con)
    class_p= classification_report(y_test,pred)
    class_out.append(class_p)
    cohe=cohen_kappa_score(y_test, pred)
    cohen.append(cohe)
    i +=1
print('score :\n', np.mean(score),'\ncohen: \n',np.mean(cohen),'\nconfusion \n',confusion, 'classification: \n',class_out)
# Out:
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# score :
#  0.9934358974358973
# cohen:
#  0.9823172793444078
# confusion
#  [array([[1424,    7],
#        [   9,  510]]), array([[1510,    8],
#        [   5,  427]]), array([[1444,    5],
#        [  10,  491]]), array([[1467,    2],
#        [   8,  473]]), array([[1485,    6],
#        [   6,  453]]), array([[1465,    8],
#        [   5,  472]]), array([[1463,    1],
#        [   9,  477]]), array([[1461,    6],
#        [   7,  476]]), array([[1489,    4],
#        [   8,  449]]), array([[1428,    4],
#        [  10,  508]])] classification:
#  ['              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      0.99      1431\n         1.0       0.99      0.98      0.98       519\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      0.99      1.00      1518\n         1.0       0.98      0.99      0.99       432\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      0.99      1449\n         1.0       0.99      0.98      0.98       501\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      1.00      1469\n         1.0       1.00      0.98      0.99       481\n\n    accuracy                           0.99      1950\n   macro avg       1.00      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1491\n         1.0       0.99      0.99      0.99       459\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      0.99      1.00      1473\n         1.0       0.98      0.99      0.99       477\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      1.00      1464\n         1.0       1.00      0.98      0.99       486\n\n    accuracy                           0.99      1950\n   macro avg       1.00      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1467\n         1.0       0.99      0.99      0.99       483\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      1.00      1493\n         1.0       0.99      0.98      0.99       457\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      1.00      1432\n         1.0       0.99      0.98      0.99       518\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n']
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, cohen_kappa_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

cohen=[]
score=[]
confusion=[]
class_out=[]
for i in range(10): 
    model=SVC()
    x=total_wine.drop(columns='wine_type')
    y=total_wine['wine_type']
    x_train,x_test,y_train, y_test=train_test_split(x,y, test_size=0.3)
    scale=MinMaxScaler()
    x_train_n= scale.fit_transform(x_train)
    x_train_n= pd.DataFrame(x_train_n, columns=x_train.columns)
    x_test_n= scale.fit_transform(x_test)
    x_test_n= pd.DataFrame(x_test_n, columns=x_test.columns)
    model.fit(x_train_n, y_train)
    pred=model.predict(x_test_n)
    scor=accuracy_score(pred, y_test)
    score.append(scor)

    con=confusion_matrix(y_test, pred)
    confusion.append(con)
    class_p= classification_report(y_test,pred)
    class_out.append(class_p)
    cohe=cohen_kappa_score(y_test, pred)
    cohen.append(cohe)
    i +=1
print('score :\n', np.mean(score),'\ncohen: \n',np.mean(cohen),'\nconfusion \n',confusion, 'classification: \n',class_out)
# Out:
# score :
#  0.9963589743589741
# cohen:
#  0.9900769797489009
# confusion
#  [array([[1477,    2],
#        [   2,  469]]), array([[1476,    0],
#        [   5,  469]]), array([[1487,    1],
#        [   7,  455]]), array([[1483,    2],
#        [   4,  461]]), array([[1478,    1],
#        [   6,  465]]), array([[1465,    6],
#        [   5,  474]]), array([[1477,    4],
#        [   5,  464]]), array([[1463,    3],
#        [   4,  480]]), array([[1486,    2],
#        [   5,  457]]), array([[1453,    3],
#        [   4,  490]])] classification:
#  ['              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1479\n         1.0       1.00      1.00      1.00       471\n\n    accuracy                           1.00      1950\n   macro avg       1.00      1.00      1.00      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1476\n         1.0       1.00      0.99      0.99       474\n\n    accuracy                           1.00      1950\n   macro avg       1.00      0.99      1.00      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1488\n         1.0       1.00      0.98      0.99       462\n\n    accuracy                           1.00      1950\n   macro avg       1.00      0.99      0.99      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1485\n         1.0       1.00      0.99      0.99       465\n\n    accuracy                           1.00      1950\n   macro avg       1.00      1.00      1.00      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1479\n         1.0       1.00      0.99      0.99       471\n\n    accuracy                           1.00      1950\n   macro avg       1.00      0.99      1.00      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1471\n         1.0       0.99      0.99      0.99       479\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1481\n         1.0       0.99      0.99      0.99       469\n\n    accuracy                           1.00      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1466\n         1.0       0.99      0.99      0.99       484\n\n    accuracy                           1.00      1950\n   macro avg       1.00      0.99      1.00      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1488\n         1.0       1.00      0.99      0.99       462\n\n    accuracy                           1.00      1950\n   macro avg       1.00      0.99      1.00      1950\nweighted avg       1.00      1.00      1.00      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1456\n         1.0       0.99      0.99      0.99       494\n\n    accuracy                           1.00      1950\n   macro avg       1.00      0.99      1.00      1950\nweighted avg       1.00      1.00      1.00      1950\n']

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, cohen_kappa_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier

cohen=[]
score=[]
confusion=[]
class_out=[]
for i in range(10): 
    model=AdaBoostClassifier()
    x=total_wine.drop(columns='wine_type')
    y=total_wine['wine_type']
    x_train,x_test,y_train, y_test=train_test_split(x,y, test_size=0.3)
    
    scale=MinMaxScaler()
    x_train_n= scale.fit_transform(x_train)
    x_train_n= pd.DataFrame(x_train_n, columns=x_train.columns)
    x_test_n= scale.fit_transform(x_test)
    x_test_n= pd.DataFrame(x_test_n, columns=x_test.columns)
    model.fit(x_train_n, y_train)
    pred=model.predict(x_test_n)
    scor=accuracy_score(pred, y_test)
    score.append(scor)

    con=confusion_matrix(y_test, pred)
    confusion.append(con)
    class_p= classification_report(y_test,pred)
    class_out.append(class_p)
    cohe=cohen_kappa_score(y_test, pred)
    cohen.append(cohe)
    i +=1
print('score :\n', np.mean(score),'\ncohen: \n',np.mean(cohen),'\nconfusion \n',confusion, 'classification: \n',class_out)
# Out:
# score :
#  0.992
# cohen:
#  0.978529826634513
# confusion
#  [array([[1436,   10],
#        [  10,  494]]), array([[1468,    8],
#        [   7,  467]]), array([[1464,    8],
#        [   4,  474]]), array([[1466,    6],
#        [   6,  472]]), array([[1471,    7],
#        [  10,  462]]), array([[1453,    7],
#        [   6,  484]]), array([[1448,    8],
#        [   8,  486]]), array([[1472,    4],
#        [  13,  461]]), array([[1463,    6],
#        [   9,  472]]), array([[1455,    7],
#        [  12,  476]])] classification:
#  ['              precision    recall  f1-score   support\n\n         0.0       0.99      0.99      0.99      1446\n         1.0       0.98      0.98      0.98       504\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      0.99      0.99      1476\n         1.0       0.98      0.99      0.98       474\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      0.99      1.00      1472\n         1.0       0.98      0.99      0.99       478\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1472\n         1.0       0.99      0.99      0.99       478\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      0.99      1478\n         1.0       0.99      0.98      0.98       472\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       1.00      1.00      1.00      1460\n         1.0       0.99      0.99      0.99       490\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      0.99      0.99      1456\n         1.0       0.98      0.98      0.98       494\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      0.99      1476\n         1.0       0.99      0.97      0.98       474\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.98      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      0.99      1469\n         1.0       0.99      0.98      0.98       481\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n', '              precision    recall  f1-score   support\n\n         0.0       0.99      1.00      0.99      1462\n         1.0       0.99      0.98      0.98       488\n\n    accuracy                           0.99      1950\n   macro avg       0.99      0.99      0.99      1950\nweighted avg       0.99      0.99      0.99      1950\n']

# %%
results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/nm/btrww2_94pncl34mb0yt49j80000gn/T/ipykernel_9835/962467392.py in <module>
# ----> 1 results
#
# NameError: name 'results' is not defined

# %%
# The scoring can be‘accuracy’, ‘balanced_accuracy’, ‘roc_auc’ ,‘f1’, ‘neg_mean_absolute_error’ (= -sigma(|y-yp])/n, y is observation and yp is prediction), ‘neg_root_mean_squared_error’, ‘r2’
from sklearn.model_selection import cross_val_score, StratifiedKFold, train_test_split, KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, cohen_kappa_score, confusion_matrix, classification_report
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
import seaborn as sns
x=total_wine.drop(columns='wine_type')
y=total_wine['wine_type']
x_train,x_test,y_train, y_test=train_test_split(x,y, test_size=0.3)
scale=MinMaxScaler()
x_train_n= scale.fit_transform(x_train)
x_train_n= pd.DataFrame(x_train_n, columns=x_train.columns)
x_test_n= scale.fit_transform(x_test)
x_test_n= pd.DataFrame(x_test_n, columns=x_test.columns)
models=[]
models.append(('ADA', AdaBoostClassifier()))
models.append(('svc', SVC()))
models.append(('LGR', LogisticRegression()))
models.append(('DT', DecisionTreeClassifier()))
models.append(('RF', RandomForestClassifier()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('Gu', GaussianNB()))
models.append(('kNN', KNeighborsClassifier()))

results=[]
names=[]

for name, model in models:
    kf=KFold(n_splits=10, random_state=7, shuffle=True)
    cv_result=cross_val_score(model, x_train_n, y_train,cv=kf, scoring='f1')

    results.append(cv_result)
    names.append(name)
    print(name, '%0.4f'%np.mean(cv_result), '%0.4f'%np.std(cv_result))
    plt.bar(name,1-np.mean(cv_result))
plt.show()
# Out:
# ADA 0.9878 0.0056
# svc 0.9923 0.0044
# LGR 0.9895 0.0062
# DT 0.9707 0.0081
# RF 0.9882 0.0085
# LDA 0.9907 0.0065
# Gu 0.9670 0.0112
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# kNN 0.9861 0.0071
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
importance_f[7]
# Out:
# array([0.00228722, 0.01051243, 0.00083572, 0.00831317, 0.01570266,
#        0.00096767, 0.02674291, 0.0094128 , 0.005894  , 0.00453046,
#        0.00092369, 0.00145151])

# %%
# The scoring can be‘accuracy’, ‘balanced_accuracy’, ‘roc_auc’ ,‘f1’, ‘neg_mean_absolute_error’ (= -sigma(|y-yp])/n, y is observation and yp is prediction), 
# ‘neg_root_mean_squared_error’, ‘r2’
from sklearn.model_selection import cross_val_score, StratifiedKFold, train_test_split, KFold
from sklearn.inspection import permutation_importance
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, cohen_kappa_score, confusion_matrix, classification_report
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
x=total_wine.drop(columns='wine_type')
y=total_wine['wine_type']
x_train,x_test,y_train, y_test=train_test_split(x,y, test_size=0.3)
scale=MinMaxScaler()
x_train_n= scale.fit_transform(x_train)
x_train_n= pd.DataFrame(x_train_n, columns=x_train.columns)
x_test_n= scale.fit_transform(x_test)
x_test_n= pd.DataFrame(x_test_n, columns=x_test.columns)
models=[]
models.append(('ABC', AdaBoostClassifier()))
models.append(('SVC', SVC()))
models.append(('LR', LogisticRegression()))
models.append(('DTC', DecisionTreeClassifier()))
models.append(('RFC', RandomForestClassifier()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('GNB', GaussianNB()))
models.append(('kNN', KNeighborsClassifier()))

results=[]
names=[]
importance_f=[]
fig= plt.figure(figsize=(12,6))

for name, model in models:
    kf=StratifiedKFold(n_splits=10, random_state=7, shuffle=True)
    cv_result=cross_val_score(model, x_train_n, y_train,cv=kf, scoring='accuracy')
    results.append(cv_result)
    names.append(name)
    print(name, '%0.4f'%np.mean(cv_result), '%0.4f'%np.std(cv_result))

    plt.bar(name,np.mean(cv_result))
    plt.ylim(0.97,1)
    model.fit(x_train_n, y_train)
    re=permutation_importance(model, x_train_n,y_train, scoring='accuracy')
    importance = re.importances_mean
    importance_f.append(importance)

plt.legend(labels=['ABC: AdaBoostClassifier', 'SVC: SVC','LR: LogisticRegression', 'DTC: DecisionTreeClassifier',
'RFC: RandomForestClassifier', 'LDA: LinearDiscriminantAnalysis', 'GNB: GaussianNB', 'kNN: KNeighborsClassifier '])
plt.xlabel('Models')
plt.ylabel('Accuracy score of model performance')

plt.show()
count=0
fig= plt.figure(figsize=(12,16))
labels=['AdaBoostClassifier', 'SVC','LogisticRegression', 'DecisionTreeClassifier',
'RandomForestClassifier', 'LinearDiscriminantAnalysis', 'GaussianNB', 'KNeighborsClassifier ']
for i in range(4):
    for j in range(2):
        plt.subplot2grid((4,2),(i,j))
        plt.bar([x for x in x_train_n.columns], importance_f[count])
        plt.tight_layout(pad=2)
        plt.title('Feature importance for model {}'.format(labels[count]))

        plt.ylabel('Accuracy score')
        plt.xticks(rotation=90)
        count +=1
# Out:
# ABC 0.9930 0.0032
# SVC 0.9960 0.0022
# LR 0.9943 0.0030
# DTC 0.9853 0.0044
# RFC 0.9945 0.0020
# LDA 0.9949 0.0034
# GNB 0.9853 0.0047
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# kNN 0.9930 0.0031
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/marziehbaes/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
total_wine.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.169147          0.334504     0.314973        5.333531
# std         1.053421          0.144827     0.127374        4.406070
# min         5.700000          0.160000     0.050000        1.200000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max         9.800000          0.670000     0.560000       15.000000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.053274            30.029244            114.993074     0.994679
# std       0.020607            15.960009             53.957347     0.002801
# min       0.028000             6.000000             19.000000     0.989900
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.102000            61.000000            206.000000     0.999392
#
#                 pH    sulphates      alcohol      quality    wine_type
# count  6497.000000  6497.000000  6497.000000  6497.000000  6497.000000
# mean      3.216860     0.525724    10.483953     5.829614     0.246114
# std       0.145589     0.122707     1.133738     0.731124     0.430779
# min       2.970000     0.350000     9.000000     5.000000     0.000000
# 25%       3.110000     0.430000     9.500000     5.000000     0.000000
# 50%       3.210000     0.510000    10.300000     6.000000     0.000000
# 75%       3.320000     0.600000    11.300000     6.000000     0.000000
# max       3.500000     0.790000    12.700000     7.000000     1.000000
